# %% [markdown]
# # Data Science Prep Course - Unit 3 (Statistics for Data Science), Lesson 3 (The Normal Distribution and the Central Limit Theorem).
#
# This document contains solutions for the statistics drills in Unit 3, Lesson 3 of the Thinkful Data Science Prep Course.

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

from scipy.stats import ttest_ind

# %matplotlib inline

# %% [markdown]
# ## Compute the p-value for binomial distributions with varying probabilities, trial sizes and sample sizes.

# %%
pop1 = np.random.binomial(10, 0.2, 10000)   # trial size = 10, probability of success = .2
pop2 = np.random.binomial(10, 0.5, 10000)   # trial size = 10, probability of success = .5

# Sample size = 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.87 	std:  1.36128615654
# sample 2 mean:  5.0 	std:  1.68522995464
# Ttest_indResult(statistic=14.375800285390467, pvalue=3.5580208213805547e-32)

# %%
# Increase sample size from 100 to 1000
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.974 	std:  1.26147691219
# sample 2 mean:  5.003 	std:  1.52937601655
# Ttest_indResult(statistic=48.291237872719094, pvalue=0.0)

# %%
# Decrease sample size to 20
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.6 	std:  1.0677078252
# sample 2 mean:  4.9 	std:  1.7
# Ttest_indResult(statistic=7.1653633377370767, pvalue=3.9292566356844863e-08)

# %% [markdown]
# ### What values change and which remain the same, when the sample size is changed?
#
# The pvalue accuracy increases as the sample size increases.

# %%
# Change the probability of success values from 0.2 and 0.5 to 0.3 and 0.4.
pop1 = np.random.binomial(10, 0.3, 10000)   # trial size = 10, probability of success = .3
pop2 = np.random.binomial(10, 0.4, 10000)   # trial size = 10, probability of success = .4

# Sample size = 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  3.21 	std:  1.38776799214
# sample 2 mean:  3.86 	std:  1.73216627377
# Ttest_indResult(statistic=2.9138723742863011, pvalue=0.0040004582050682976)

# %% [markdown]
# ### What changes when the probability of success values change?
#
# As the probability of success values become more similar, the pvalue increases, since the distributions become more similar.

# %%
pop1 = np.random.poisson(1.0, 10000)   # expectation of interval = 1.0, sample size
pop2 = np.random.poisson(.5, 10000)

# Sample size = 100
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.013 	std:  1.03770467861
# sample 2 mean:  0.488 	std:  0.675171089428
# Ttest_indResult(statistic=-13.403410249673614, pvalue=4.9279661489473568e-39)

# %% [markdown]
# ### When the distribution type is changed to Poisson, do the sample mena values still accuractely represent the population values?
#
# Yes, as can be seen above, the sample means are the average value for the populations.
