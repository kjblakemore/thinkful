# %% [markdown]
# # Data Science Prep Course - Unit 3 (Statistics for Data Science), Lesson 3 (The Normal Distribution and the Central Limit Theorem), Project 7 (Exploring the Central Limit Theorem)
#
# This document contains solutions for the statistics drills in Unit 3, Lesson 3, Project 7 of the Thinkful Data Science Prep Course.

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

from scipy.stats import ttest_ind

# %matplotlib inline

# %% [markdown]
# ## Compute the mean, standard deviation, t-statistic and p-value for binomial distributions with varying probabilities, trial sizes and sample sizes.

# %%
pop1 = np.random.binomial(10, 0.2, 10000)   # trial size = 10, probability of success = .2
pop2 = np.random.binomial(10, 0.5, 10000)   # trial size = 10, probability of success = .5

# Sample size = 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.76 	std:  1.20099958368
# sample 2 mean:  5.18 	std:  1.44485293369
# Ttest_indResult(statistic=18.11158050645847, pvalue=2.2328721258298658e-43)

# %%
# Increase sample size from 100 to 1000
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.979 	std:  1.25720284759
# sample 2 mean:  4.988 	std:  1.60681548412
# Ttest_indResult(statistic=46.615703513514269, pvalue=2.2804217465860036e-316)

# %%
# Decrease sample size to 20
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  2.15 	std:  1.65151445649
# sample 2 mean:  4.65 	std:  1.35185058346
# Ttest_indResult(statistic=5.1059036878708755, pvalue=1.0455621194807589e-05)

# %% [markdown]
# ### What values change and which remain the same, when the sample size is changed?
#
# The means stay the same, but the t-statistic increases and the p-value decreases as the sample size increases.

# %%
# Change the probability of success values from 0.2 and 0.5 to 0.3 and 0.4.
pop1 = np.random.binomial(10, 0.3, 10000)   # trial size = 10, probability of success = .3
pop2 = np.random.binomial(10, 0.4, 10000)   # trial size = 10, probability of success = .4

# Sample size = 100
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  3.05 	std:  1.43788038445
# sample 2 mean:  3.91 	std:  1.73836129731
# Ttest_indResult(statistic=3.7929992410780171, pvalue=0.00019953308379846871)

# %% [markdown]
# ### What changes when the probability of success values change?
#
# The means become more similar, the t-statistic decreases and the p-value increases.

# %%
pop1 = np.random.poisson(1.0, 10000)   # expectation of interval = 1.0, sample size
pop2 = np.random.poisson(.5, 10000)

# Sample size = 100
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 

plt.subplot(1, 2, 2)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

print('sample 1 mean: ', sample1.mean(), '\tstd: ', sample1.std())
print('sample 2 mean: ', sample2.mean(), '\tstd: ', sample2.std())

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# sample 1 mean:  1.03 	std:  1.01247222184
# sample 2 mean:  0.498 	std:  0.698567104865
# Ttest_indResult(statistic=-13.66976771452156, pvalue=1.6082834651629985e-40)

# %% [markdown]
# ### When the distribution type is changed to Poisson, do the sample mean values still accuractely represent the population values?
#
# Yes, as can be seen above, the sample means are the average values for the populations.
